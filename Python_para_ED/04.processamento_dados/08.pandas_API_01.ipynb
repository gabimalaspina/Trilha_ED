# %%
# boas práticas para programação em produção:
# 0. utilizar arquivo .py em vez de notebooks; importar todas as bibliotecas no início do código;
# 1. criar funções separadas para cada ação que queremos executar;
# 2. determinar os tipos de variáveis que as funções devem receber;
# 3. reaproveitar o código ao máximo, evitar repetições;
# 4. utilizar try/except para deixar mais profissional, exibindo erro f'Erro: {e}'
# 5. em vez de print, utilizar biblioteca/módulo logging para exibir mensagens durante execução;

# OBS: aqui, faremos uma versão para teste; depois, o código será refatorado seguindo os princípios acima, para ficar mais profissional

# %%
import pandas as pd
import requests, logging

from datetime import datetime as dt

# %%
# o problema consiste em:
# 1. extrair json (dic) com os dados da API referente a um produto específico, que vamos escolher;
# 2. ao obter os dados, vamos criar um dataframe com as colunas que nos interessam;
# 3. dentre as colunas que nos interessam, vamos verificar a necessidade de fazer alguma transformação;
# 4. tudo estando redondo, vamos salvar as informações em um arquivo csv.

# %%
# parte 1 - função para extrair as informações do site a partir do código do produto (str)

def extraindo_infos(cod_produto:str):
    
    url = 'https://world.openfoodfacts.org/api/v2/product/'
    url_completa = url + cod_produto

    resposta = requests.get(url_completa)

    dados_brutos = resposta.json()

    return dados_brutos

# %%
url_completa
# Out:
# 'https://world.openfoodfacts.org/api/v2/product/7891000369371'

# %%
cod_produto = '7891000369371'

# %%
extraindo_infos(cod_produto)

# %%
# criando um dataframe com as colunas de nosso interesse: id do produto, nome do produto, 

dados_brutos = resposta.json() # note que isso é o que a nossa função extraindo_infos retorna!

dados_produto = dados_brutos.get('product', None)

# %%
dados2 = pd.json_normalize(dados_produto)
dados2
# Out:
#              _id                                    _keywords  \
# 0  7891000369371  [80g, ao, chocolate, crunch, leite, pacote]
#
#   added_countries_tags allergens allergens_from_ingredients  \
# 0                   []
#
#   allergens_from_user allergens_hierarchy allergens_tags  brands brands_tags  \
# 0               (pt)                   []             []  CRUNCH    [crunch]
#
#    ... nutriscore.2023.grade nutriscore.2023.nutrients_available  \
# 0  ...               unknown                                   0
#
#   nutriscore.2023.nutriscore_applicable nutriscore.2023.nutriscore_computed  \
# 0                                     0                                   0
#
#                     selected_images.front.display.es  \
# 0  https://images.openfoodfacts.org/images/produc...
#
#                     selected_images.front.display.pt  \
# 0  https://images.openfoodfacts.org/images/produc...
#
#                       selected_images.front.small.es  \
# 0  https://images.openfoodfacts.org/images/produc...
#
#                       selected_images.front.small.pt  \
# 0  https://images.openfoodfacts.org/images/produc...
#
#                       selected_images.front.thumb.es  \
# 0  https://images.openfoodfacts.org/images/produc...
#
#                       selected_images.front.thumb.pt
# 0  https://images.openfoodfacts.org/images/produc...
#
# [1 rows x 437 columns]

# %%
# agora, vamos utilizar um recurso do pandas para trabalhar com json e deixar em formato bidimensional (LXC): json_normalize

dados = pd.json_normalize(dados_brutos)
dados
# Out:
#             code  status status_verbose    product._id  \
# 0  7891000369371       1  product found  7891000369371
#
#                              product._keywords product.added_countries_tags  \
# 0  [80g, ao, chocolate, crunch, leite, pacote]                           []
#
#   product.allergens product.allergens_from_ingredients  \
# 0
#
#   product.allergens_from_user product.allergens_hierarchy  ...  \
# 0                       (pt)                           []  ...
#
#                                       product.states  \
# 0  en:to-be-completed, en:nutrition-facts-complet...
#
#                             product.states_hierarchy  \
# 0  [en:to-be-completed, en:nutrition-facts-comple...
#
#                                  product.states_tags product.traces  \
# 0  [en:to-be-completed, en:nutrition-facts-comple...
#
#   product.traces_from_ingredients product.traces_from_user  \
# 0                                                    (pt)
#
#   product.traces_hierarchy  product.traces_tags  \
# 0                       []                   []
#
#    product.unknown_nutrients_tags product.weighers_tags
# 0                              []                    []
#
# [1 rows x 440 columns]

# %%
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Columns: 437 entries, _id to selected_images.front.thumb.pt
# dtypes: float64(7), int64(283), object(147)
# memory usage: 3.5+ KB

# %%
for i in dados2.columns:
    print(i)
# Out:
# _id
# _keywords
# added_countries_tags
# allergens
# allergens_from_ingredients
# allergens_from_user
# allergens_hierarchy
# allergens_tags
# brands
# brands_tags
# categories_properties_tags
# checkers_tags
# code
# codes_tags
# complete
# completeness
# correctors_tags
# countries
# countries_hierarchy
# countries_lc
# countries_tags
# created_t
# creator
# data_quality_bugs_tags
# data_quality_errors_tags
# data_quality_info_tags
# data_quality_tags
# data_quality_warnings_tags
# ecoscore_grade
# ecoscore_tags
# editors_tags
# entry_dates_tags
# food_groups_tags
# id
# image_front_small_url
# image_front_thumb_url
# image_front_url
# image_small_url
# image_thumb_url
# image_url
# informers_tags
# ingredients_lc
# interface_version_created
# interface_version_modified
# lang
# languages_hierarchy
# languages_tags
# last_edit_dates_tags
# last_image_dates_tags
# last_image_t
# last_modified_t
# lc
# main_countries_tags
# max_imgid
# misc_tags
# nova_group_debug
# nova_group_error
# nova_groups_tags
# nutrient_levels_tags
# nutriscore_2021_tags
# nutriscore_2023_tags
# nutriscore_grade
# nutriscore_tags
# nutriscore_version
# nutrition_data_per
# nutrition_data_prepared_per
# nutrition_grade_fr
# nutrition_grades
# nutrition_grades_tags
# nutrition_score_beverage
# nutrition_score_debug
# nutrition_score_warning_no_fiber
# nutrition_score_warning_no_fruits_vegetables_nuts
# packaging_materials_tags
# packaging_recycling_tags
# packaging_shapes_tags
# packagings
# photographers_tags
# pnns_groups_1
# pnns_groups_1_tags
# pnns_groups_2
# pnns_groups_2_tags
# popularity_key
# product_name
# product_name_es
# product_name_pt
# product_quantity
# quantity
# removed_countries_tags
# rev
# serving_size
# states
# states_hierarchy
# states_tags
# traces
# traces_from_ingredients
# traces_from_user
# traces_hierarchy
# traces_tags
# unknown_nutrients_tags
# weighers_tags
# ecoscore_data.adjustments.origins_of_ingredients.aggregated_origins
# ecoscore_data.adjustments.origins_of_ingredients.epi_score
# ecoscore_data.adjustments.origins_of_ingredients.epi_value
# ecoscore_data.adjustments.origins_of_ingredients.origins_from_origins_field
# ecoscore_data.adjustments.origins_of_ingredients.transportation_score
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ad
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.al
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.at
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ax
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ba
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.be
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.bg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ch
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.cy
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.cz
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.de
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.dk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.dz
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ee
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.eg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.es
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.fi
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.fo
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.fr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.gg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.gi
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.gr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.hr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.hu
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ie
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.il
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.im
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.is
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.it
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.je
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.lb
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.li
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.lt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.lu
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.lv
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ly
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ma
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.mc
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.md
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.me
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.mk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.mt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.nl
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.no
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.pl
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ps
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.pt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ro
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.rs
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.se
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.si
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.sj
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.sk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.sm
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.sy
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.tn
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.tr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.ua
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.uk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.us
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.va
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.world
# ecoscore_data.adjustments.origins_of_ingredients.transportation_scores.xk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_value
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ad
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.al
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.at
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ax
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ba
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.be
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.bg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ch
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.cy
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.cz
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.de
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.dk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.dz
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ee
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.eg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.es
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.fi
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.fo
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.fr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.gg
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.gi
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.gr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.hr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.hu
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ie
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.il
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.im
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.is
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.it
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.je
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.lb
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.li
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.lt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.lu
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.lv
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ly
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ma
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.mc
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.md
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.me
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.mk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.mt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.nl
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.no
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.pl
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ps
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.pt
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ro
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.rs
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.se
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.si
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.sj
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.sk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.sm
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.sy
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.tn
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.tr
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.ua
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.uk
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.us
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.va
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.world
# ecoscore_data.adjustments.origins_of_ingredients.transportation_values.xk
# ecoscore_data.adjustments.origins_of_ingredients.value
# ecoscore_data.adjustments.origins_of_ingredients.values.ad
# ecoscore_data.adjustments.origins_of_ingredients.values.al
# ecoscore_data.adjustments.origins_of_ingredients.values.at
# ecoscore_data.adjustments.origins_of_ingredients.values.ax
# ecoscore_data.adjustments.origins_of_ingredients.values.ba
# ecoscore_data.adjustments.origins_of_ingredients.values.be
# ecoscore_data.adjustments.origins_of_ingredients.values.bg
# ecoscore_data.adjustments.origins_of_ingredients.values.ch
# ecoscore_data.adjustments.origins_of_ingredients.values.cy
# ecoscore_data.adjustments.origins_of_ingredients.values.cz
# ecoscore_data.adjustments.origins_of_ingredients.values.de
# ecoscore_data.adjustments.origins_of_ingredients.values.dk
# ecoscore_data.adjustments.origins_of_ingredients.values.dz
# ecoscore_data.adjustments.origins_of_ingredients.values.ee
# ecoscore_data.adjustments.origins_of_ingredients.values.eg
# ecoscore_data.adjustments.origins_of_ingredients.values.es
# ecoscore_data.adjustments.origins_of_ingredients.values.fi
# ecoscore_data.adjustments.origins_of_ingredients.values.fo
# ecoscore_data.adjustments.origins_of_ingredients.values.fr
# ecoscore_data.adjustments.origins_of_ingredients.values.gg
# ecoscore_data.adjustments.origins_of_ingredients.values.gi
# ecoscore_data.adjustments.origins_of_ingredients.values.gr
# ecoscore_data.adjustments.origins_of_ingredients.values.hr
# ecoscore_data.adjustments.origins_of_ingredients.values.hu
# ecoscore_data.adjustments.origins_of_ingredients.values.ie
# ecoscore_data.adjustments.origins_of_ingredients.values.il
# ecoscore_data.adjustments.origins_of_ingredients.values.im
# ecoscore_data.adjustments.origins_of_ingredients.values.is
# ecoscore_data.adjustments.origins_of_ingredients.values.it
# ecoscore_data.adjustments.origins_of_ingredients.values.je
# ecoscore_data.adjustments.origins_of_ingredients.values.lb
# ecoscore_data.adjustments.origins_of_ingredients.values.li
# ecoscore_data.adjustments.origins_of_ingredients.values.lt
# ecoscore_data.adjustments.origins_of_ingredients.values.lu
# ecoscore_data.adjustments.origins_of_ingredients.values.lv
# ecoscore_data.adjustments.origins_of_ingredients.values.ly
# ecoscore_data.adjustments.origins_of_ingredients.values.ma
# ecoscore_data.adjustments.origins_of_ingredients.values.mc
# ecoscore_data.adjustments.origins_of_ingredients.values.md
# ecoscore_data.adjustments.origins_of_ingredients.values.me
# ecoscore_data.adjustments.origins_of_ingredients.values.mk
# ecoscore_data.adjustments.origins_of_ingredients.values.mt
# ecoscore_data.adjustments.origins_of_ingredients.values.nl
# ecoscore_data.adjustments.origins_of_ingredients.values.no
# ecoscore_data.adjustments.origins_of_ingredients.values.pl
# ecoscore_data.adjustments.origins_of_ingredients.values.ps
# ecoscore_data.adjustments.origins_of_ingredients.values.pt
# ecoscore_data.adjustments.origins_of_ingredients.values.ro
# ecoscore_data.adjustments.origins_of_ingredients.values.rs
# ecoscore_data.adjustments.origins_of_ingredients.values.se
# ecoscore_data.adjustments.origins_of_ingredients.values.si
# ecoscore_data.adjustments.origins_of_ingredients.values.sj
# ecoscore_data.adjustments.origins_of_ingredients.values.sk
# ecoscore_data.adjustments.origins_of_ingredients.values.sm
# ecoscore_data.adjustments.origins_of_ingredients.values.sy
# ecoscore_data.adjustments.origins_of_ingredients.values.tn
# ecoscore_data.adjustments.origins_of_ingredients.values.tr
# ecoscore_data.adjustments.origins_of_ingredients.values.ua
# ecoscore_data.adjustments.origins_of_ingredients.values.uk
# ecoscore_data.adjustments.origins_of_ingredients.values.us
# ecoscore_data.adjustments.origins_of_ingredients.values.va
# ecoscore_data.adjustments.origins_of_ingredients.values.world
# ecoscore_data.adjustments.origins_of_ingredients.values.xk
# ecoscore_data.adjustments.origins_of_ingredients.warning
# ecoscore_data.adjustments.packaging.non_recyclable_and_non_biodegradable_materials
# ecoscore_data.adjustments.packaging.value
# ecoscore_data.adjustments.packaging.warning
# ecoscore_data.adjustments.production_system.labels
# ecoscore_data.adjustments.production_system.value
# ecoscore_data.adjustments.production_system.warning
# ecoscore_data.adjustments.threatened_species.warning
# ecoscore_data.agribalyse.warning
# ecoscore_data.missing.categories
# ecoscore_data.missing.ingredients
# ecoscore_data.missing.labels
# ecoscore_data.missing.origins
# ecoscore_data.missing.packagings
# ecoscore_data.missing_agribalyse_match_warning
# ecoscore_data.missing_key_data
# ecoscore_data.status
# images.1.sizes.100.h
# images.1.sizes.100.w
# images.1.sizes.400.h
# images.1.sizes.400.w
# images.1.sizes.full.h
# images.1.sizes.full.w
# images.1.uploaded_t
# images.1.uploader
# images.2.sizes.100.h
# images.2.sizes.100.w
# images.2.sizes.400.h
# images.2.sizes.400.w
# images.2.sizes.full.h
# images.2.sizes.full.w
# images.2.uploaded_t
# images.2.uploader
# images.front_es.angle
# images.front_es.coordinates_image_size
# images.front_es.geometry
# images.front_es.imgid
# images.front_es.normalize
# images.front_es.rev
# images.front_es.sizes.100.h
# images.front_es.sizes.100.w
# images.front_es.sizes.200.h
# images.front_es.sizes.200.w
# images.front_es.sizes.400.h
# images.front_es.sizes.400.w
# images.front_es.sizes.full.h
# images.front_es.sizes.full.w
# images.front_es.white_magic
# images.front_es.x1
# images.front_es.x2
# images.front_es.y1
# images.front_es.y2
# images.front_pt.angle
# images.front_pt.coordinates_image_size
# images.front_pt.geometry
# images.front_pt.imgid
# images.front_pt.normalize
# images.front_pt.rev
# images.front_pt.sizes.100.h
# images.front_pt.sizes.100.w
# images.front_pt.sizes.200.h
# images.front_pt.sizes.200.w
# images.front_pt.sizes.400.h
# images.front_pt.sizes.400.w
# images.front_pt.sizes.full.h
# images.front_pt.sizes.full.w
# images.front_pt.white_magic
# images.front_pt.x1
# images.front_pt.x2
# images.front_pt.y1
# images.front_pt.y2
# languages.en:portuguese
# languages.en:spanish
# languages_codes.es
# languages_codes.pt
# nutriments.carbohydrates
# nutriments.carbohydrates_serving
# nutriments.carbohydrates_unit
# nutriments.carbohydrates_value
# nutriments.energy
# nutriments.energy-kcal
# nutriments.energy-kcal_serving
# nutriments.energy-kcal_unit
# nutriments.energy-kcal_value
# nutriments.energy-kcal_value_computed
# nutriments.energy-kj
# nutriments.energy-kj_serving
# nutriments.energy-kj_unit
# nutriments.energy-kj_value
# nutriments.energy-kj_value_computed
# nutriments.energy_serving
# nutriments.energy_unit
# nutriments.energy_value
# nutriments.fat
# nutriments.fat_serving
# nutriments.fat_unit
# nutriments.fat_value
# nutriments.proteins
# nutriments.proteins_serving
# nutriments.proteins_unit
# nutriments.proteins_value
# nutriscore.2021.category_available
# nutriscore.2021.data.energy
# nutriscore.2021.data.fiber
# nutriscore.2021.data.fruits_vegetables_nuts_colza_walnut_olive_oils
# nutriscore.2021.data.is_beverage
# nutriscore.2021.data.is_cheese
# nutriscore.2021.data.is_fat
# nutriscore.2021.data.is_water
# nutriscore.2021.data.proteins
# nutriscore.2021.data.saturated_fat
# nutriscore.2021.data.sodium
# nutriscore.2021.data.sugars
# nutriscore.2021.grade
# nutriscore.2021.nutrients_available
# nutriscore.2021.nutriscore_applicable
# nutriscore.2021.nutriscore_computed
# nutriscore.2023.category_available
# nutriscore.2023.data.energy
# nutriscore.2023.data.fiber
# nutriscore.2023.data.fruits_vegetables_legumes
# nutriscore.2023.data.is_beverage
# nutriscore.2023.data.is_cheese
# nutriscore.2023.data.is_fat_oil_nuts_seeds
# nutriscore.2023.data.is_red_meat_product
# nutriscore.2023.data.is_water
# nutriscore.2023.data.proteins
# nutriscore.2023.data.salt
# nutriscore.2023.data.saturated_fat
# nutriscore.2023.data.sugars
# nutriscore.2023.grade
# nutriscore.2023.nutrients_available
# nutriscore.2023.nutriscore_applicable
# nutriscore.2023.nutriscore_computed
# selected_images.front.display.es
# selected_images.front.display.pt
# selected_images.front.small.es
# selected_images.front.small.pt
# selected_images.front.thumb.es
# selected_images.front.thumb.pt

# %%
dados.to_json('./dados_crunch_amostra.json')

# %%
# selecionando as colunas de nosso interesse: # image_front_small_url

dados_target = dados[['product._id', 'product.product_name', 'product.brands', 'product.image_front_small_url']]
dados_target
# Out:
#      product._id                  product.product_name product.brands  \
# 0  7891000369371  Chocolate Ao Leite Crunch Pacote 80g         CRUNCH
#
#                        product.image_front_small_url
# 0  https://images.openfoodfacts.org/images/produc...

# %%
# parte 2 - criando um dataframe com as colunas de nosso interesse a partir dos dados brutos que obtivemos no requests.get 

def selecionando_dados(dados_brutos):
    dados_produto = dados_brutos.get('product', None)
    dados = pd.json_normalize(dados_produto) # transformando o json em dataframe, bidimensional (LXC)
    dados_target = dados[['_id', 'product_name', 'brands', 'image_front_small_url', 'created_t']] # selecionando colunas de nosso interesse

    return dados_target # aqui, retornamos um dataframe com as colunas que nos interessam

# %%
selecionando_dados(dados_brutos)
# Out:
#              _id                          product_name  brands  \
# 0  7891000369371  Chocolate Ao Leite Crunch Pacote 80g  CRUNCH
#
#                                image_front_small_url   created_t
# 0  https://images.openfoodfacts.org/images/produc...  1686621225

# %%
dados_target
# Out:
#      product._id                  product.product_name product.brands  \
# 0  7891000369371  Chocolate Ao Leite Crunch Pacote 80g         CRUNCH
#
#                        product.image_front_small_url
# 0  https://images.openfoodfacts.org/images/produc...

# %%
dados_target['product.created_t'] = pd.to_datetime(dados_target['product.created_t'], units='s')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product.created_t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 dados_target['product.created_t'] = pd.to_datetime(dados_target['product.created_t'], units='s')
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'product.created_t'

# %%
# parte 3 - agora, vamos incluir algumas colunas e ver se precisamos fazer alguma transformação nos dados que já obtivemos

def modelagem_final(dados_target):
    # primeiro: converter a coluna created_t para o formato datetime em data
    dados_target['created_t'] = pd.to_datetime(dados_target['created_t'], units='s')
    # depois: incluir coluna com a data de inclusão do registro no dataframe

    return(dados_target)

# %%
modelagem_final(dados_target)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product.created_t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 modelagem_final(dados_target)
#
# Cell In[80], line 5, in modelagem_final(dados_target)
#       3 def modelagem_final(dados_target):
#       4     # primeiro: converter a coluna created_t para o formato datetime em data
# ----> 5     dados_target['product.created_t'] = pd.to_datetime(dados_target['product.created_t'], units='s')
#       6     # depois: incluir coluna com a data de inclusão do registro no dataframe
#       8     return(dados_target)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'product.created_t'
